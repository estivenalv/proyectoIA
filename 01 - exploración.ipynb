# %% [markdown]
# <a href="https://colab.research.google.com/github/estivenalv/proyectoIA/blob/main/01%20-%20exploraci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '.'
# !chmod 600 ./kaggle.json
# !kaggle competitions download -c udea-ai4eng-20242
# Out:
# ...
#  25% 5.00M/20.1M [00:00<00:00, 31.9MB/s]
# 100% 20.1M/20.1M [00:00<00:00, 88.5MB/s]

# %%
# !unzip udea*.zip > /dev/null

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("train.csv")
df.describe()
# Out:
#                   ID        PERIODO
# count  692500.000000  692500.000000
# mean   494606.130576   20198.366679
# std    285585.209455      10.535037
# min         1.000000   20183.000000
# 25%    247324.750000   20195.000000
# 50%    494564.500000   20195.000000
# 75%    741782.500000   20203.000000
# max    989286.000000   20213.000000

# %%
df.tail()
# Out:
#             ID  PERIODO                  ESTU_PRGM_ACADEMICO  \
# 692495   25096    20195                             BIOLOGIA
# 692496  754213    20212                           PSICOLOGIA
# 692497  504185    20183  ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 692498  986620    20195                           PSICOLOGIA
# 692499  933374    20195                           PSICOLOGIA
#
#        ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 692495             LA GUAJIRA         Entre 500 mil y menos de 1 millón
# 692496        NORTE SANTANDER  Entre 2.5 millones y menos de 4 millones
# 692497                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
# 692498                 TOLIMA  Entre 2.5 millones y menos de 4 millones
# 692499              ANTIOQUIA  Entre 5.5 millones y menos de 7 millones
#
#        ESTU_HORASSEMANATRABAJA FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 692495     Entre 11 y 20 horas            Estrato 2                 Si
# ...

# %%
df = df[['ESTU_HORASSEMANATRABAJA', 'ESTU_PRGM_ACADEMICO', 'RENDIMIENTO_GLOBAL']]
df.tail()
# Out:
#        ESTU_HORASSEMANATRABAJA                  ESTU_PRGM_ACADEMICO  \
# 692495     Entre 11 y 20 horas                             BIOLOGIA
# 692496         Más de 30 horas                           PSICOLOGIA
# 692497       Menos de 10 horas  ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 692498       Menos de 10 horas                           PSICOLOGIA
# 692499         Más de 30 horas                           PSICOLOGIA
#
#        RENDIMIENTO_GLOBAL
# 692495         medio-alto
# 692496               bajo
# 692497         medio-bajo
# 692498               bajo
# 692499               alto

# %%
df.tail().ESTU_HORASSEMANATRABAJA	.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ESTU_HORASSEMANATRABAJA'>

# %%
df.tail().ESTU_PRGM_ACADEMICO.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ESTU_PRGM_ACADEMICO'>
